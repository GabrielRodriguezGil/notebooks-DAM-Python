# %% [markdown]
# # LIBRO DE LA RATA DICCIONARIOS

# %% [markdown]
# ## Basic Operations

# %%
lista_llaves = [1,2,3,4,5,6]
lista_valores = ["rojo","amarillo"]
diccionarie = dict(zip(lista_llaves, lista_valores))
diccionarie
# Out:
# {1: 'rojo', 2: 'amarillo'}

# %%
D = dict.fromkeys(['name', 'age'], 4)
D
# Out:
# {'name': 4, 'age': 4}

# %%
D = dict.fromkeys(['name', 'age'], 4)
D.values()
# Out:
# dict_values([4, 4])

# %%
D.items()
# Out:
# dict_items([('name', 4), ('age', 4)])

# %%
D1 = dict(name='Bob', age=40)

# %%
D.update(D1)
D
# Out:
# {'name': 'Bob', 'age': 40}
